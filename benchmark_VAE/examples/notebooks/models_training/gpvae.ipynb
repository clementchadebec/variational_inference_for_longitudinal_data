# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import torch

device = "cuda" if torch.cuda.is_available() else 'cpu'


# %load_ext autoreload
# %autoreload 2

# %%
from utils import make_batched_masks

PATH = '/gpfswork/rech/wlr/uhw48em/rvae/data/rotated_mnist/missing_for_gpvae_60.npz'

data = np.load(PATH)

train_data = torch.tensor(data['x_train_full'].reshape(-1, 8, 1, 28, 28))
train_pix_mask = torch.ones_like(train_data).type(torch.bool)#torch.tensor(data['m_train_miss'].reshape(-1, 8, 1, 28, 28)).type(torch.bool)
train_seq_mask = make_batched_masks(train_data, 0.3, 64).type(torch.bool)

eval_data = torch.tensor(data['x_test_full'].reshape(-1, 8, 1, 28, 28))
eval_pix_mask =  torch.ones_like(eval_data).type(torch.bool)#torch.tensor(data['m_test_miss'].reshape(-1, 8, 1, 28, 28)).type(torch.bool)
eval_seq_mask = make_batched_masks(eval_data, 0.3, 64).type(torch.bool)
       
print(train_data.shape)
# Out:
# torch.Size([10000, 8, 1, 28, 28])

# %%
from utils import Encoder_HMNIST, Decoder_HMNIST, My_MaskedDataset, make_batched_masks

import torch
from pythae.models import GPVAE, GPVAEConfig
from pythae.trainers import BaseTrainerConfig, BaseTrainer
import numpy as np

#train_mask = make_batched_masks(train_data, 0., 128).type(torch.bool)
#eval_mask = make_batched_masks(eval_data, 0., 128).type(torch.bool)


config = GPVAEConfig(
        input_dim=(1, 28, 28),
        time_length=train_data.shape[1],
        latent_dim=16,
        sigma=1,
        length_scale=2,
        beta=0.8,
        reconstruction_loss="mse",
        out_channels_time_cnn=256
)

training_config = BaseTrainerConfig(
    num_epochs=20,
    learning_rate=1e-3,
    batch_size=64,
    steps_saving=None,
    steps_predict=None,
    shuffle=True,
    keep_best_on_train=True
)

encoder = Encoder_HMNIST(config)
decoder = Decoder_HMNIST(config)

model = GPVAE(config, encoder, decoder).cuda()

### Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=training_config.learning_rate, eps=1e-4)

### Scheduler
scheduler = torch.optim.lr_scheduler.MultiStepLR(
    optimizer,
    milestones=[50, 100, 125, 150],
    gamma=0.5,
    verbose=True
)

#train_seq_mask = torch.ones(train_data.shape[:2], requires_grad=False).type(torch.bool)
#eval_seq_mask = torch.ones(eval_data.shape[:2], requires_grad=False).type(torch.bool)

train_dataset = My_MaskedDataset(train_data, train_seq_mask, pix_mask=train_pix_mask)
eval_dataset = My_MaskedDataset(eval_data, eval_seq_mask, pix_mask=eval_pix_mask)

trainer = BaseTrainer(
            model=model,
            train_dataset=train_dataset,
            eval_dataset=eval_dataset,
            training_config=training_config,
            optimizer=optimizer,
            scheduler=scheduler,
            callbacks=None,
        )
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
trainer.train()
# Out:
# /home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/gp_vae/gpvae_model.py:239: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   xs = torch.range(1, T)
# Model passed sanity check !
#
# Created dummy_output_dir/GPVAE_training_2022-12-20_14-03-46.
# Training config, checkpoints and final model will be saved here.
#
# Successfully launched training !
# Training of epoch 1/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 1/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 75.9685
# Eval loss: 53.2994
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 2/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 2/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.1464
# Eval loss: 53.0933
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 3/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 3/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0848
# Eval loss: 53.08
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 4/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 4/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0781
# Eval loss: 53.0769
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 5/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 5/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0761
# Eval loss: 53.0756
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 6/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 6/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0752
# Eval loss: 53.0748
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 7/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 7/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0747
# Eval loss: 53.0745
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 8/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 8/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0744
# Eval loss: 53.0743
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 9/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 9/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0743
# Eval loss: 53.0741
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 10/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 10/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0741
# Eval loss: 53.0741
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 11/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 11/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.074
# Eval loss: 53.074
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 12/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 12/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.074
# Eval loss: 53.074
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 13/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 13/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0739
# Eval loss: 53.0739
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 14/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 14/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0739
# Eval loss: 53.0739
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 15/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 15/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0739
# Eval loss: 53.0738
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 16/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 16/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0738
# Eval loss: 53.074
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 17/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 17/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0738
# Eval loss: 53.0738
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 18/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 18/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0738
# Eval loss: 53.0737
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 19/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 19/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0738
# Eval loss: 53.0738
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# keeps best
# Training of epoch 20/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# Eval of epoch 20/20:   0%|          | 0/157 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.0738
# Eval loss: 53.0737
# --------------------------------------------------------------------------
# Training ended!
# Saved final model in dummy_output_dir/GPVAE_training_2022-12-20_14-03-46/final_model
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
def set_inputs_to_device(inputs):

    inputs_on_device = inputs

    #if self.device == "cuda":
    cuda_inputs = dict.fromkeys(inputs)

    for key in inputs.keys():
        if torch.is_tensor(inputs[key]):
            cuda_inputs[key] = inputs[key].cuda()

        else:
            cuda_inputs = inputs[key]
    inputs_on_device = cuda_inputs

    return inputs_on_device

# %%
from torch.utils.data import DataLoader
loader = DataLoader(
            dataset=train_dataset,
            batch_size=10,
            shuffle=False,
        )
inputs = next(iter(loader))
inputs = set_inputs_to_device(inputs)
recon = model(inputs).recon_x.reshape(10, 8, -1).detach().cpu()

# %%
lim = train_data.shape[1]
im_size = 28#64

torch.manual_seed(8)
#idx = torch.randperm(len(train_data))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')

# %%
test_data = torch.load(os.path.join('/gpfswork/rech/wlr/uhw48em/rvae/data/rotated_mnist/test_mnist_rotated_8.pt'), map_location="cpu")
model.get_nll(test_data.cuda(), n_samples=100)
# Out:
# Current nll at 0: -961.6952009623382
# Current nll at 1000: -1014.2046553830997
# Current nll at 2000: -1013.4350109449992
# Current nll at 3000: -1013.9181800757596
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/gpvae.ipynb Cell 8' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/gpvae.ipynb#ch0000007vscode-remote?line=0'>1</a> test_data = torch.load(os.path.join('/gpfswork/rech/wlr/uhw48em/rvae/data/rotated_mnist/test_mnist_rotated_8.pt'), map_location="cpu")
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/gpvae.ipynb#ch0000007vscode-remote?line=1'>2</a> model.get_nll(test_data.cuda(), n_samples=100)
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/models/gp_vae/gpvae_model.py:317, in GPVAE.get_nll(self, data, n_samples, batch_size)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/gp_vae/gpvae_model.py?line=312'>313</a> qz_x = self.posterior_dist(mean=mu, log_covar=log_var)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/gp_vae/gpvae_model.py?line=314'>315</a> z = qz_x.rsample()
# --> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/gp_vae/gpvae_model.py?line=316'>317</a> log_q_z_given_x = qz_x.log_prob(z).sum(dim=-1)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/gp_vae/gpvae_model.py?line=317'>318</a> log_p_z = pz.log_prob(z).sum(dim=-1)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/gp_vae/gpvae_model.py?line=319'>320</a> z = torch.transpose(z, 2, 1)
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/multivariate_normal.py:214, in MultivariateNormal.log_prob(self, value)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/multivariate_normal.py?line=211'>212</a> def log_prob(self, value):
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/multivariate_normal.py?line=212'>213</a>     if self._validate_args:
# --> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/multivariate_normal.py?line=213'>214</a>         self._validate_sample(value)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/multivariate_normal.py?line=214'>215</a>     diff = value - self.loc
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/multivariate_normal.py?line=215'>216</a>     M = _batch_mahalanobis(self._unbroadcasted_scale_tril, diff)
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py:292, in Distribution._validate_sample(self, value)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=289'>290</a>     return
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=290'>291</a> assert support is not None
# --> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=291'>292</a> valid = support.check(value)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=292'>293</a> if not valid.all():
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=293'>294</a>     raise ValueError(
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=294'>295</a>         "Expected value argument "
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=295'>296</a>         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=298'>299</a>         f"but found invalid values:\n{value}"
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/distribution.py?line=299'>300</a>     )
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/constraints.py:214, in _IndependentConstraint.check(self, value)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/constraints.py?line=211'>212</a>     raise ValueError(f"Expected value.dim() >= {expected} but got {value.dim()}")
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/constraints.py?line=212'>213</a> result = result.reshape(result.shape[:result.dim() - self.reinterpreted_batch_ndims] + (-1,))
# --> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/constraints.py?line=213'>214</a> result = result.all(-1)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/distributions/constraints.py?line=214'>215</a> return result
#
# KeyboardInterrupt:

# %%
lim = train_data.shape[1]
im_size = 28#64

torch.manual_seed(8)
idx = torch.randperm(len(train_data))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(train_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(train_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(train_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(train_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')

# %%
from pythae.data.datasets import DatasetOutput
from torch.utils.data import Dataset


class DynBinarizedMNIST(Dataset):
    def __init__(self, data):
        self.data = data.type(torch.float)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        x = self.data[index]
        #x = (x > torch.distributions.Uniform(0, 1).sample(x.shape).to(x.device)).float()
        return DatasetOutput(data=x)

# %%
from pythae.models.nn import BaseEncoder, BaseDecoder
from pythae.models.base.base_utils import ModelOutput
import torch.nn as nn


### Define paper encoder network
class VAEEncoder(BaseEncoder):
    def __init__(self, args: dict):
        BaseEncoder.__init__(self)
        self.input_dim = args.input_dim
        self.latent_dim = args.latent_dim


        self.fc1 = nn.Linear(np.prod(args.input_dim), 200)
        self.fc2 = nn.Linear(200, 200)

        self.embedding = nn.Linear(200, self.latent_dim)
        self.log_var = nn.Linear(200, self.latent_dim)
        #self.context = nn.Linear(200, self.context_dim)

    def forward(self, x):
        output = ModelOutput()

        out = torch.relu(self.fc1(x))
        out = torch.relu(self.fc2(out))

        output["embedding"] = self.embedding(out)
        output["log_covariance"] = self.log_var(out)
        #output["context"] = self.context(out)

        return output

### Define paper decoder network
class VAEDecoder(BaseDecoder):
    def __init__(self, args: dict):
        BaseDecoder.__init__(self)

        self.input_dim = args.input_dim
        self.latent_dim = args.latent_dim

        self.fc1 = nn.Linear(self.latent_dim, 200)
        self.fc2 = nn.Linear(200, 200)
        self.fc3 = nn.Linear(200, np.prod(args.input_dim))


    def forward(self, z: torch.Tensor):

        output = ModelOutput()

        out = torch.relu(self.fc1(z))
        out = torch.relu(self.fc2(out))
        out = torch.sigmoid(self.fc3(out))

        output["reconstruction"] = out.reshape((z.shape[0],) + self.input_dim)

        return output



### Define paper encoder network
class TimeEncoder(BaseEncoder):
    def __init__(self, args: dict):
        BaseEncoder.__init__(self)
        self.input_dim = args.input_dim
        self.latent_dim = args.latent_dim
        self.context_dim = args.context_dim


        self.fc1 = nn.Linear(np.prod(args.input_dim), 500)
        self.fc2 = nn.Linear(500, 200)

        #self.time_fc1 = nn.Linear(1, 50)
        #self.time_fc2 = nn.Linear(50, 50)

        self.embedding = nn.Linear(200, self.latent_dim)
        self.log_var = nn.Linear(200, self.latent_dim)
        #self.context = nn.Linear(250, self.context_dim)

    def forward(self, x, t=None):
        output = ModelOutput()

        out = torch.relu(self.fc1(x))
        out = torch.relu(self.fc2(out))

        #time_out = torch.relu(self.time_fc1(t))
        #time_out = torch.relu(self.time_fc2(time_out))
        #out = torch.cat((out, time_out), dim=-1)

        output["embedding"] = self.embedding(out)
        output["log_covariance"] = self.log_var(out)
        #output["context"] = self.context(out)

        return output

### Define paper decoder network
class TimeDecoder(BaseDecoder):
    def __init__(self, args: dict):
        BaseDecoder.__init__(self)

        self.input_dim = args.input_dim
        self.latent_dim = args.latent_dim

        self.fc1 = nn.Linear(self.latent_dim+1, 500)
        self.fc2 = nn.Linear(500, 200)

        #self.time_fc1 = nn.Linear(1, 50)
        #self.time_fc2 = nn.Linear(50, 50)

        self.fc3 = nn.Linear(200, np.prod(args.input_dim))


    def forward(self, z: torch.Tensor, t=None):

        output = ModelOutput()

        out = torch.relu(self.fc1(z))
        out = torch.relu(self.fc2(out))

        #time_out = torch.relu(self.time_fc1(t))
        #time_out = torch.relu(self.time_fc2(time_out))
        #out = torch.cat((out, time_out), dim=-1)

        out = torch.sigmoid(self.fc3(out))

        output["reconstruction"] = out.reshape((z.shape[0],) + self.input_dim)

        return output


### Define paper encoder network
class Encoder(BaseEncoder):
    def __init__(self, args: dict):
        BaseEncoder.__init__(self)
        self.input_dim = args.input_dim
        self.latent_dim = args.latent_dim
        self.context_dim = args.context_dim


        self.fc1 = nn.Linear(np.prod(args.input_dim), 500)
        self.fc2 = nn.Linear(500, 200)

        self.embedding = nn.Linear(200, self.latent_dim)
        self.log_var = nn.Linear(200, self.latent_dim)
        self.context = nn.Linear(200, self.context_dim)

    def forward(self, x):
        output = ModelOutput()

        out = torch.relu(self.fc1(x.reshape(-1, np.prod(self.input_dim))))
        out = torch.relu(self.fc2(out))

        output["embedding"] = self.embedding(out)
        output["log_covariance"] = self.log_var(out)
        output["context"] = self.context(out)

        return output

### Define paper decoder network
class Decoder(BaseDecoder):
    def __init__(self, args: dict):
        BaseDecoder.__init__(self)

        self.input_dim = args.input_dim
        self.latent_dim = args.latent_dim

        self.fc1 = nn.Linear(self.latent_dim, 500)
        self.fc2 = nn.Linear(500, 200)


        self.fc3 = nn.Linear(200, np.prod(args.input_dim))


    def forward(self, z: torch.Tensor):

        output = ModelOutput()

        out = torch.relu(self.fc1(z))
        out = torch.relu(self.fc2(out))

        out = torch.sigmoid(self.fc3(out))

        output["reconstruction"] = out.reshape((z.shape[0],) + self.input_dim)

        return output

# %% [markdown]
# ## VAE

# %% [markdown]
# ## CVAE

# %%
from pythae.models import LCVAE, LCVAE_Config
from pythae.trainers import BaseTrainerConfig, BaseTrainer
import torch.optim as optim


config = LCVAE_Config(
    input_dim=(1, 28, 28),
    latent_dim=2,
    n_obs_per_ind=8
)

encoder = TimeEncoder(config)
decoder = TimeDecoder(config)

vae = LCVAE(config, encoder, decoder).cuda()


train_dataset = DynBinarizedMNIST(train_data.reshape(-1, 8, 784))
eval_dataset = DynBinarizedMNIST(eval_data.reshape(-1, 8, 784))

training_config = BaseTrainerConfig(
    num_epochs=1000,
    learning_rate=1e-3,
    batch_size=100
)

### Optimizer
vae_optimizer = torch.optim.Adam(vae.parameters(), lr=training_config.learning_rate, eps=1e-4)

### Scheduler
vae_scheduler = torch.optim.lr_scheduler.MultiStepLR(
    vae_optimizer, milestones=[10000], gamma=10**(-1/7), verbose=True
)

vae_trainer = BaseTrainer(
        model=vae,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        training_config=training_config,
        optimizer=vae_optimizer,
        scheduler=vae_scheduler,
        callbacks=None,
    )
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
_ = vae({'data': train_data[:5].cuda().reshape((-1, 8, 28*28)).float()}, epoch=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000047vscode-remote?line=0'>1</a> _ = vae({'data': train_data[:5].cuda().reshape((-1, 8, 28*28)).float()}, epoch=0)
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py:89, in LCVAE.forward(self, inputs, **kwargs)
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=84'>85</a> t = torch.linspace(0, 1, self.n_obs).repeat(x.shape[0], 1).to(x.device)
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=85'>86</a> x_t = torch.cat((t.unsqueeze(-1), x.reshape((x.shape[0], self.n_obs,) + x.shape[2:])), dim=-1)
# ---> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=88'>89</a> encoder_output = self.encoder(x_t)#.reshape((x.shape[0]*self.n_obs,) + x.shape[2:]))#, torch.arange(0, self.n_obs).to(x.device).repeat(x.shape[0]).unsqueeze(-1) / self.n_obs)
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=89'>90</a> mu, log_var = encoder_output.embedding, encoder_output.log_covariance
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=90'>91</a> std = torch.exp(0.5 * log_var)
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 7' in TimeEncoder.forward(self, x, t)
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=78'>79</a> def forward(self, x, t=None):
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=79'>80</a>     output = ModelOutput()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=81'>82</a>     out = torch.relu(self.fc1(x))
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=82'>83</a>     out = torch.relu(self.fc2(out))
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=84'>85</a>     #time_out = torch.relu(self.time_fc1(t))
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=85'>86</a>     #time_out = torch.relu(self.time_fc2(time_out))
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=86'>87</a>     #out = torch.cat((out, time_out), dim=-1)
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=112'>113</a> def forward(self, input: Tensor) -> Tensor:
# --> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=113'>114</a>     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (40x785 and 784x500)

# %%
vae_trainer.train()
# Out:
# Model passed sanity check !
#
# Created dummy_output_dir/VAE_IAF_training_2022-10-14_20-37-00.
# Training config, checkpoints and final model will be saved here.
#
# Successfully launched training !
#
# Training of epoch 1/1000: 100%|██████████| 100/100 [00:01<00:00, 63.15batch/s]
# Eval of epoch 1/1000: 100%|██████████| 100/100 [00:00<00:00, 148.78batch/s]
# --------------------------------------------------------------------------
# Train loss: 66.2867
# Eval loss: 54.5661
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 2/1000: 100%|██████████| 100/100 [00:01<00:00, 74.09batch/s]
# Eval of epoch 2/1000: 100%|██████████| 100/100 [00:00<00:00, 248.69batch/s]
# --------------------------------------------------------------------------
# Train loss: 53.9584
# Eval loss: 52.1471
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 3/1000: 100%|██████████| 100/100 [00:01<00:00, 72.27batch/s]
# Eval of epoch 3/1000: 100%|██████████| 100/100 [00:00<00:00, 228.49batch/s]
# --------------------------------------------------------------------------
# Train loss: 50.6103
# Eval loss: 48.8062
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 4/1000: 100%|██████████| 100/100 [00:00<00:00, 124.34batch/s]
# Eval of epoch 4/1000: 100%|██████████| 100/100 [00:00<00:00, 487.99batch/s]
# --------------------------------------------------------------------------
# Train loss: 48.0907
# Eval loss: 47.2235
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 5/1000: 100%|██████████| 100/100 [00:00<00:00, 142.90batch/s]
# Eval of epoch 5/1000: 100%|██████████| 100/100 [00:00<00:00, 541.20batch/s]
# --------------------------------------------------------------------------
# Train loss: 46.9568
# Eval loss: 46.4951
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 6/1000: 100%|██████████| 100/100 [00:00<00:00, 136.72batch/s]
# Eval of epoch 6/1000: 100%|██████████| 100/100 [00:00<00:00, 592.35batch/s]
# --------------------------------------------------------------------------
# Train loss: 46.3333
# Eval loss: 46.0488
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 7/1000: 100%|██████████| 100/100 [00:00<00:00, 154.17batch/s]
# Eval of epoch 7/1000: 100%|██████████| 100/100 [00:00<00:00, 581.25batch/s]
# --------------------------------------------------------------------------
# Train loss: 45.9495
# Eval loss: 45.6813
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 8/1000: 100%|██████████| 100/100 [00:00<00:00, 151.17batch/s]
# Eval of epoch 8/1000: 100%|██████████| 100/100 [00:00<00:00, 592.53batch/s]
# --------------------------------------------------------------------------
# Train loss: 45.6239
# Eval loss: 45.3713
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 9/1000: 100%|██████████| 100/100 [00:00<00:00, 162.92batch/s]
# Eval of epoch 9/1000: 100%|██████████| 100/100 [00:00<00:00, 537.67batch/s]
# --------------------------------------------------------------------------
# Train loss: 45.322
# Eval loss: 45.0523
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 10/1000: 100%|██████████| 100/100 [00:00<00:00, 169.25batch/s]
# Eval of epoch 10/1000: 100%|██████████| 100/100 [00:00<00:00, 603.12batch/s]
# --------------------------------------------------------------------------
# Train loss: 45.0797
# Eval loss: 44.7829
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 11/1000: 100%|██████████| 100/100 [00:00<00:00, 152.04batch/s]
# Eval of epoch 11/1000: 100%|██████████| 100/100 [00:00<00:00, 574.82batch/s]
# --------------------------------------------------------------------------
# Train loss: 44.8088
# Eval loss: 44.6812
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 12/1000: 100%|██████████| 100/100 [00:00<00:00, 161.48batch/s]
# Eval of epoch 12/1000: 100%|██████████| 100/100 [00:00<00:00, 600.90batch/s]
# --------------------------------------------------------------------------
# Train loss: 44.5711
# Eval loss: 44.3317
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 13/1000: 100%|██████████| 100/100 [00:00<00:00, 150.99batch/s]
# Eval of epoch 13/1000: 100%|██████████| 100/100 [00:00<00:00, 576.11batch/s]
# --------------------------------------------------------------------------
# Train loss: 44.3178
# Eval loss: 44.1058
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 14/1000: 100%|██████████| 100/100 [00:00<00:00, 158.12batch/s]
# Eval of epoch 14/1000: 100%|██████████| 100/100 [00:00<00:00, 610.52batch/s]
# --------------------------------------------------------------------------
# Train loss: 44.0575
# Eval loss: 43.8706
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 15/1000: 100%|██████████| 100/100 [00:00<00:00, 163.38batch/s]
# Eval of epoch 15/1000: 100%|██████████| 100/100 [00:00<00:00, 596.90batch/s]
# --------------------------------------------------------------------------
# Train loss: 43.7843
# Eval loss: 43.5614
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 16/1000: 100%|██████████| 100/100 [00:00<00:00, 160.85batch/s]
# Eval of epoch 16/1000: 100%|██████████| 100/100 [00:00<00:00, 555.02batch/s]
# --------------------------------------------------------------------------
# Train loss: 43.5231
# Eval loss: 43.3381
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 17/1000: 100%|██████████| 100/100 [00:00<00:00, 144.19batch/s]
# Eval of epoch 17/1000: 100%|██████████| 100/100 [00:00<00:00, 460.65batch/s]
# --------------------------------------------------------------------------
# Train loss: 43.2861
# Eval loss: 43.2369
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 18/1000: 100%|██████████| 100/100 [00:00<00:00, 158.63batch/s]
# Eval of epoch 18/1000: 100%|██████████| 100/100 [00:00<00:00, 608.97batch/s]
# --------------------------------------------------------------------------
# Train loss: 43.1073
# Eval loss: 42.9602
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 19/1000: 100%|██████████| 100/100 [00:00<00:00, 145.21batch/s]
# Eval of epoch 19/1000: 100%|██████████| 100/100 [00:00<00:00, 419.93batch/s]
# --------------------------------------------------------------------------
# Train loss: 42.8446
# Eval loss: 42.7575
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 20/1000: 100%|██████████| 100/100 [00:00<00:00, 151.04batch/s]
# Eval of epoch 20/1000: 100%|██████████| 100/100 [00:00<00:00, 557.62batch/s]
# --------------------------------------------------------------------------
# Train loss: 42.6423
# Eval loss: 42.5842
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 21/1000: 100%|██████████| 100/100 [00:00<00:00, 144.62batch/s]
# Eval of epoch 21/1000: 100%|██████████| 100/100 [00:00<00:00, 525.32batch/s]
# --------------------------------------------------------------------------
# Train loss: 42.4253
# Eval loss: 42.401
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 22/1000: 100%|██████████| 100/100 [00:00<00:00, 145.90batch/s]
# Eval of epoch 22/1000: 100%|██████████| 100/100 [00:00<00:00, 496.66batch/s]
# --------------------------------------------------------------------------
# Train loss: 42.267
# Eval loss: 42.2775
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 23/1000: 100%|██████████| 100/100 [00:00<00:00, 152.29batch/s]
# Eval of epoch 23/1000: 100%|██████████| 100/100 [00:00<00:00, 604.69batch/s]
# --------------------------------------------------------------------------
# Train loss: 42.0679
# Eval loss: 42.198
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 24/1000: 100%|██████████| 100/100 [00:00<00:00, 149.06batch/s]
# Eval of epoch 24/1000: 100%|██████████| 100/100 [00:00<00:00, 490.39batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.9188
# Eval loss: 41.9735
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 25/1000: 100%|██████████| 100/100 [00:00<00:00, 151.53batch/s]
# Eval of epoch 25/1000: 100%|██████████| 100/100 [00:00<00:00, 529.48batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.7784
# Eval loss: 41.8443
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 26/1000: 100%|██████████| 100/100 [00:00<00:00, 167.20batch/s]
# Eval of epoch 26/1000: 100%|██████████| 100/100 [00:00<00:00, 611.72batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.6499
# Eval loss: 41.8314
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 27/1000: 100%|██████████| 100/100 [00:00<00:00, 160.58batch/s]
# Eval of epoch 27/1000: 100%|██████████| 100/100 [00:00<00:00, 604.65batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.4882
# Eval loss: 41.6955
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 28/1000: 100%|██████████| 100/100 [00:00<00:00, 158.90batch/s]
# Eval of epoch 28/1000: 100%|██████████| 100/100 [00:00<00:00, 602.92batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.3548
# Eval loss: 41.6582
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 29/1000: 100%|██████████| 100/100 [00:00<00:00, 161.49batch/s]
# Eval of epoch 29/1000: 100%|██████████| 100/100 [00:00<00:00, 576.45batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.2621
# Eval loss: 41.6436
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 30/1000: 100%|██████████| 100/100 [00:00<00:00, 156.79batch/s]
# Eval of epoch 30/1000: 100%|██████████| 100/100 [00:00<00:00, 604.96batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.1255
# Eval loss: 41.346
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 31/1000: 100%|██████████| 100/100 [00:00<00:00, 181.29batch/s]
# Eval of epoch 31/1000: 100%|██████████| 100/100 [00:00<00:00, 686.60batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.0161
# Eval loss: 41.3931
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 32/1000: 100%|██████████| 100/100 [00:00<00:00, 154.02batch/s]
# Eval of epoch 32/1000: 100%|██████████| 100/100 [00:00<00:00, 600.92batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.9014
# Eval loss: 41.3503
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 33/1000: 100%|██████████| 100/100 [00:00<00:00, 149.05batch/s]
# Eval of epoch 33/1000: 100%|██████████| 100/100 [00:00<00:00, 605.57batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.801
# Eval loss: 41.1527
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 34/1000: 100%|██████████| 100/100 [00:00<00:00, 175.52batch/s]
# Eval of epoch 34/1000: 100%|██████████| 100/100 [00:00<00:00, 613.23batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.6698
# Eval loss: 41.1135
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 35/1000: 100%|██████████| 100/100 [00:00<00:00, 163.99batch/s]
# Eval of epoch 35/1000: 100%|██████████| 100/100 [00:00<00:00, 601.23batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.5515
# Eval loss: 41.0479
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 36/1000: 100%|██████████| 100/100 [00:00<00:00, 139.73batch/s]
# Eval of epoch 36/1000: 100%|██████████| 100/100 [00:00<00:00, 592.10batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.4781
# Eval loss: 40.9838
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 37/1000: 100%|██████████| 100/100 [00:00<00:00, 157.28batch/s]
# Eval of epoch 37/1000: 100%|██████████| 100/100 [00:00<00:00, 570.20batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.3828
# Eval loss: 41.0172
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 38/1000: 100%|██████████| 100/100 [00:00<00:00, 138.55batch/s]
# Eval of epoch 38/1000: 100%|██████████| 100/100 [00:00<00:00, 531.55batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.2697
# Eval loss: 40.8755
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 39/1000: 100%|██████████| 100/100 [00:00<00:00, 161.86batch/s]
# Eval of epoch 39/1000: 100%|██████████| 100/100 [00:00<00:00, 601.55batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.1952
# Eval loss: 40.732
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 40/1000: 100%|██████████| 100/100 [00:00<00:00, 160.04batch/s]
# Eval of epoch 40/1000: 100%|██████████| 100/100 [00:00<00:00, 587.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.1167
# Eval loss: 40.7372
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 41/1000: 100%|██████████| 100/100 [00:00<00:00, 141.34batch/s]
# Eval of epoch 41/1000: 100%|██████████| 100/100 [00:00<00:00, 543.61batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.0199
# Eval loss: 40.6468
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 42/1000: 100%|██████████| 100/100 [00:00<00:00, 150.40batch/s]
# Eval of epoch 42/1000: 100%|██████████| 100/100 [00:00<00:00, 557.26batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.9499
# Eval loss: 40.6374
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 43/1000: 100%|██████████| 100/100 [00:00<00:00, 148.11batch/s]
# Eval of epoch 43/1000: 100%|██████████| 100/100 [00:00<00:00, 532.61batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.8607
# Eval loss: 40.6132
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 44/1000: 100%|██████████| 100/100 [00:00<00:00, 143.23batch/s]
# Eval of epoch 44/1000: 100%|██████████| 100/100 [00:00<00:00, 568.08batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.8096
# Eval loss: 40.5773
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 45/1000: 100%|██████████| 100/100 [00:00<00:00, 131.31batch/s]
# Eval of epoch 45/1000: 100%|██████████| 100/100 [00:00<00:00, 372.61batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.7311
# Eval loss: 40.4793
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 46/1000: 100%|██████████| 100/100 [00:00<00:00, 147.67batch/s]
# Eval of epoch 46/1000: 100%|██████████| 100/100 [00:00<00:00, 599.11batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.6981
# Eval loss: 40.5377
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 47/1000: 100%|██████████| 100/100 [00:00<00:00, 144.89batch/s]
# Eval of epoch 47/1000: 100%|██████████| 100/100 [00:00<00:00, 563.93batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.614
# Eval loss: 40.3749
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 48/1000: 100%|██████████| 100/100 [00:00<00:00, 156.93batch/s]
# Eval of epoch 48/1000: 100%|██████████| 100/100 [00:00<00:00, 532.47batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.5085
# Eval loss: 40.3212
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 49/1000: 100%|██████████| 100/100 [00:00<00:00, 151.53batch/s]
# Eval of epoch 49/1000: 100%|██████████| 100/100 [00:00<00:00, 611.85batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.4613
# Eval loss: 40.323
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 50/1000: 100%|██████████| 100/100 [00:00<00:00, 146.10batch/s]
# Eval of epoch 50/1000: 100%|██████████| 100/100 [00:00<00:00, 523.46batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.3972
# Eval loss: 40.3172
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 51/1000: 100%|██████████| 100/100 [00:00<00:00, 150.72batch/s]
# Eval of epoch 51/1000: 100%|██████████| 100/100 [00:00<00:00, 605.59batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.3514
# Eval loss: 40.3541
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 52/1000: 100%|██████████| 100/100 [00:00<00:00, 144.36batch/s]
# Eval of epoch 52/1000: 100%|██████████| 100/100 [00:00<00:00, 543.51batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.2645
# Eval loss: 40.2709
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 53/1000: 100%|██████████| 100/100 [00:00<00:00, 153.79batch/s]
# Eval of epoch 53/1000: 100%|██████████| 100/100 [00:00<00:00, 598.45batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.2275
# Eval loss: 40.1878
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 54/1000: 100%|██████████| 100/100 [00:00<00:00, 149.13batch/s]
# Eval of epoch 54/1000: 100%|██████████| 100/100 [00:00<00:00, 527.65batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.1777
# Eval loss: 40.1785
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 55/1000: 100%|██████████| 100/100 [00:00<00:00, 156.51batch/s]
# Eval of epoch 55/1000: 100%|██████████| 100/100 [00:00<00:00, 597.03batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.0825
# Eval loss: 40.176
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 56/1000: 100%|██████████| 100/100 [00:00<00:00, 150.94batch/s]
# Eval of epoch 56/1000: 100%|██████████| 100/100 [00:00<00:00, 556.69batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.0728
# Eval loss: 40.0822
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 57/1000: 100%|██████████| 100/100 [00:00<00:00, 152.02batch/s]
# Eval of epoch 57/1000: 100%|██████████| 100/100 [00:00<00:00, 632.98batch/s]
# --------------------------------------------------------------------------
# Train loss: 39.0307
# Eval loss: 40.1457
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 58/1000: 100%|██████████| 100/100 [00:00<00:00, 147.90batch/s]
# Eval of epoch 58/1000: 100%|██████████| 100/100 [00:00<00:00, 524.81batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.9705
# Eval loss: 40.013
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 59/1000: 100%|██████████| 100/100 [00:00<00:00, 139.70batch/s]
# Eval of epoch 59/1000: 100%|██████████| 100/100 [00:00<00:00, 460.91batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.9259
# Eval loss: 40.202
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 60/1000: 100%|██████████| 100/100 [00:00<00:00, 154.64batch/s]
# Eval of epoch 60/1000: 100%|██████████| 100/100 [00:00<00:00, 623.49batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.8841
# Eval loss: 40.0577
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 61/1000: 100%|██████████| 100/100 [00:00<00:00, 135.37batch/s]
# Eval of epoch 61/1000: 100%|██████████| 100/100 [00:00<00:00, 563.91batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.818
# Eval loss: 39.9421
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 62/1000: 100%|██████████| 100/100 [00:00<00:00, 148.10batch/s]
# Eval of epoch 62/1000: 100%|██████████| 100/100 [00:00<00:00, 543.40batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.7559
# Eval loss: 39.9113
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 63/1000: 100%|██████████| 100/100 [00:00<00:00, 148.67batch/s]
# Eval of epoch 63/1000: 100%|██████████| 100/100 [00:00<00:00, 660.63batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.724
# Eval loss: 39.9465
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 64/1000:  86%|████████▌ | 86/100 [00:00<00:00, 202.28batch/s]
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 64/1000: 100%|██████████| 100/100 [00:00<00:00, 106.93batch/s]
# Eval of epoch 64/1000: 100%|██████████| 100/100 [00:00<00:00, 226.97batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.705
# Eval loss: 39.8475
# --------------------------------------------------------------------------
# Training of epoch 65/1000: 100%|██████████| 100/100 [00:00<00:00, 137.68batch/s]
# Eval of epoch 65/1000: 100%|██████████| 100/100 [00:00<00:00, 433.63batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.6407
# Eval loss: 39.8291
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 765/1000: 100%|██████████| 100/100 [00:00<00:00, 100.81batch/s]
# Eval of epoch 765/1000: 100%|██████████| 100/100 [00:00<00:00, 391.59batch/s]
# --------------------------------------------------------------------------
# Train loss: 34.6666
# Eval loss: 39.4053
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 766/1000: 100%|██████████| 100/100 [00:00<00:00, 134.02batch/s]
# Eval of epoch 766/1000: 100%|██████████| 100/100 [00:00<00:00, 446.10batch/s]
# --------------------------------------------------------------------------
# Train loss: 34.6405
# Eval loss: 39.5265
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 767/1000: 100%|██████████| 100/100 [00:00<00:00, 102.04batch/s]
# Eval of epoch 767/1000: 100%|██████████| 100/100 [00:00<00:00, 312.33batch/s]
# --------------------------------------------------------------------------
# Train loss: 34.6344
# Eval loss: 39.3525
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 768/1000: 100%|██████████| 100/100 [00:00<00:00, 145.38batch/s]
# Eval of epoch 768/1000: 100%|██████████| 100/100 [00:00<00:00, 612.62batch/s]
# --------------------------------------------------------------------------
# Train loss: 34.6678
# Eval loss: 39.3245
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 769/1000:  20%|██        | 20/100 [00:00<00:00, 195.34batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000039vscode-remote?line=0'>1</a> vae_trainer.train()
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py:338, in BaseTrainer.train(self, log_output_dir)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=328'>329</a> self.callback_handler.on_epoch_begin(
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=329'>330</a>     training_config=self.training_config,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=330'>331</a>     epoch=epoch,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=331'>332</a>     train_loader=self.train_loader,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=332'>333</a>     eval_loader=self.eval_loader,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=333'>334</a> )
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=335'>336</a> metrics = {}
# --> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=337'>338</a> epoch_train_loss = self.train_step(epoch)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=338'>339</a> metrics["train_epoch_loss"] = epoch_train_loss
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=340'>341</a> if self.eval_dataset is not None:
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py:480, in BaseTrainer.train_step(self, epoch)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=475'>476</a> for inputs in self.train_loader:
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=477'>478</a>     inputs = self._set_inputs_to_device(inputs)
# --> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=479'>480</a>     model_output = self.model(
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=480'>481</a>         inputs, epoch=epoch, dataset_size=len(self.train_loader.dataset)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=481'>482</a>     )
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=483'>484</a>     self._optimizers_step(model_output)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=485'>486</a>     loss = model_output.loss
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py:86, in LCVAE.forward(self, inputs, **kwargs)
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=81'>82</a> x = inputs["data"]
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=82'>83</a> epoch = kwargs.pop("epoch", 1)
# ---> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=85'>86</a> encoder_output = self.encoder(x.reshape((x.shape[0]*self.n_obs,) + x.shape[2:]))#, torch.arange(0, self.n_obs).to(x.device).repeat(x.shape[0]).unsqueeze(-1) / self.n_obs)
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=86'>87</a> mu, log_var = encoder_output.embedding, encoder_output.log_covariance
#      <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/models/lcvae/lcvae_model.py?line=87'>88</a> std = torch.exp(0.5 * log_var)
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 7' in VAEEncoder.forward(self, x)
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=20'>21</a> def forward(self, x):
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=21'>22</a>     output = ModelOutput()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=23'>24</a>     out = torch.relu(self.fc1(x))
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=24'>25</a>     out = torch.relu(self.fc2(out))
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000006vscode-remote?line=26'>27</a>     output["embedding"] = self.embedding(out)
#
# KeyboardInterrupt:

# %%
model_rec = vae_trainer._best_model

# %%
z = torch.rand(10, 2).cuda()
gen = model_rec.generate(z).reshape(z.shape[0], 8, -1)
gen.shape
# Out:
# torch.Size([10, 8, 784])

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(gen))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')

# %%
inp = iter(vae_trainer.eval_loader).next()

emb = model_rec(inp).z.detach().cpu()
recon = model_rec(inp).recon_x.detach().cpu()

# %%
plt.scatter(emb[:8, 0], emb[:8, 1])

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(recon))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')

# %%
from pythae.models import VAE, VAEConfig
from pythae.trainers import BaseTrainerConfig, BaseTrainer
import torch.optim as optim


config = VAEConfig(
    input_dim=(1, 28, 28),
    latent_dim=64
)

encoder = VAEEncoder(config)
decoder = VAEDecoder(config)

vae = VAE(config, encoder, decoder).cuda()


train_dataset = DynBinarizedMNIST(train_data.reshape(-1, 784))
eval_dataset = DynBinarizedMNIST(eval_data.reshape(-1, 784))

training_config = BaseTrainerConfig(
    num_epochs=10,
    learning_rate=1e-3,
    batch_size=100
)

### Optimizer
vae_optimizer = torch.optim.Adam(vae.parameters(), lr=training_config.learning_rate, eps=1e-4)

### Scheduler
vae_scheduler = torch.optim.lr_scheduler.MultiStepLR(
    vae_optimizer, milestones=[10000], gamma=10**(-1/7), verbose=True
)

vae_trainer = BaseTrainer(
        model=vae,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        training_config=training_config,
        optimizer=vae_optimizer,
        scheduler=vae_scheduler,
        callbacks=None,
    )
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
vae_trainer.train()
# Out:
# Model passed sanity check !
#
# Created dummy_output_dir/VAE_training_2022-10-13_19-18-50.
# Training config, checkpoints and final model will be saved here.
#
# Successfully launched training !
#
# Training of epoch 1/10: 100%|██████████| 800/800 [00:05<00:00, 146.84batch/s]
# Eval of epoch 1/10: 100%|██████████| 800/800 [00:01<00:00, 768.99batch/s]
# --------------------------------------------------------------------------
# Train loss: 54.8252
# Eval loss: 48.6898
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 2/10: 100%|██████████| 800/800 [00:04<00:00, 187.85batch/s]
# Eval of epoch 2/10: 100%|██████████| 800/800 [00:01<00:00, 789.56batch/s]
# --------------------------------------------------------------------------
# Train loss: 45.2076
# Eval loss: 43.1598
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 3/10: 100%|██████████| 800/800 [00:04<00:00, 188.97batch/s]
# Eval of epoch 3/10: 100%|██████████| 800/800 [00:01<00:00, 749.15batch/s]
# --------------------------------------------------------------------------
# Train loss: 41.8885
# Eval loss: 41.1367
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 4/10: 100%|██████████| 800/800 [00:04<00:00, 164.41batch/s]
# Eval of epoch 4/10: 100%|██████████| 800/800 [00:01<00:00, 570.01batch/s]
# --------------------------------------------------------------------------
# Train loss: 40.1299
# Eval loss: 39.8528
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 5/10: 100%|██████████| 800/800 [00:05<00:00, 151.63batch/s]
# Eval of epoch 5/10: 100%|██████████| 800/800 [00:01<00:00, 555.45batch/s]
# --------------------------------------------------------------------------
# Train loss: 38.8872
# Eval loss: 38.416
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 6/10: 100%|██████████| 800/800 [00:04<00:00, 169.37batch/s]
# Eval of epoch 6/10: 100%|██████████| 800/800 [00:01<00:00, 749.60batch/s]
# --------------------------------------------------------------------------
# Train loss: 37.6678
# Eval loss: 37.5022
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 7/10: 100%|██████████| 800/800 [00:04<00:00, 178.01batch/s]
# Eval of epoch 7/10: 100%|██████████| 800/800 [00:01<00:00, 742.98batch/s]
# --------------------------------------------------------------------------
# Train loss: 36.9572
# Eval loss: 36.9417
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 8/10: 100%|██████████| 800/800 [00:04<00:00, 178.35batch/s]
# Eval of epoch 8/10: 100%|██████████| 800/800 [00:01<00:00, 772.70batch/s]
# --------------------------------------------------------------------------
# Train loss: 36.4688
# Eval loss: 36.6219
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 9/10: 100%|██████████| 800/800 [00:04<00:00, 179.41batch/s]
# Eval of epoch 9/10: 100%|██████████| 800/800 [00:01<00:00, 748.73batch/s]
# --------------------------------------------------------------------------
# Train loss: 36.0954
# Eval loss: 36.231
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 10/10: 100%|██████████| 800/800 [00:04<00:00, 168.15batch/s]
# Eval of epoch 10/10: 100%|██████████| 800/800 [00:01<00:00, 722.19batch/s]
# --------------------------------------------------------------------------
# Train loss: 35.8031
# Eval loss: 36.0207
# --------------------------------------------------------------------------
# Training ended!
# Saved final model in dummy_output_dir/VAE_training_2022-10-13_19-18-50/final_model
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
model_rec = vae#trainer._best_model

# %%
z = torch.rand(10, 64).cuda()
gen = model_rec.decoder(z).reconstruction.detach().cpu()
gen.shape
# Out:
# torch.Size([10, 1, 28, 28])

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(gen))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 12' in <cell line: 10>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000027vscode-remote?line=9'>10</a> for k in range(lim):
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000027vscode-remote?line=10'>11</a>     i, t = 0, k
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000027vscode-remote?line=11'>12</a>     axes[0][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000027vscode-remote?line=12'>13</a>     axes[0][k].axis('off')
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000027vscode-remote?line=13'>14</a>     i, t = 1, k
#
# IndexError: index 1 is out of bounds for dimension 1 with size 1

# %%
inp = iter(vae_trainer.eval_loader).next()

emb = model_rec(inp).z.detach().cpu()

# %%
plt.scatter(emb[:8, 0], emb[:8, 1])

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(recon))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 14' in <cell line: 10>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000029vscode-remote?line=9'>10</a> for k in range(lim):
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000029vscode-remote?line=10'>11</a>     i, t = 0, k
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000029vscode-remote?line=11'>12</a>     axes[0][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000029vscode-remote?line=12'>13</a>     axes[0][k].axis('off')
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000029vscode-remote?line=13'>14</a>     i, t = 1, k
#
# IndexError: index 1 is out of bounds for dimension 1 with size 1

# %% [markdown]
# ## LVAE

# %%
from pythae.models import LVAE_IAF, LVAE_IAF_Config

config = LVAE_IAF_Config(
    input_dim=(1, 28, 28),
    n_obs_per_ind=train_data.shape[1],
    latent_dim=2,
    n_hidden_in_made=3,
    n_made_blocks=3,
    warmup=50,
    context_dim=32,
    reconstruction_loss='bce'
)

encoder = Encoder(config)
decoder = Decoder(config)

model = LVAE_IAF(config, encoder, decoder).cuda()
model
# Out:
# LVAE_IAF(
#   (decoder): Decoder(
#     (fc1): Linear(in_features=2, out_features=500, bias=True)
#     (fc2): Linear(in_features=500, out_features=200, bias=True)
#     (fc3): Linear(in_features=200, out_features=784, bias=True)
#   )
#   (encoder): Encoder(
#     (fc1): Linear(in_features=784, out_features=500, bias=True)
#     (fc2): Linear(in_features=500, out_features=200, bias=True)
#     (embedding): Linear(in_features=200, out_features=2, bias=True)
#     (log_var): Linear(in_features=200, out_features=2, bias=True)
#     (context): Linear(in_features=200, out_features=32, bias=True)
#   )
#   (flows): ModuleList(
#     (0): IAF(
#       (net): ModuleList(
#         (0): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#         (1): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (1): IAF(
#       (net): ModuleList(
#         (0): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#         (1): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (2): IAF(
#       (net): ModuleList(
#         (0): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#         (1): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (3): IAF(
#       (net): ModuleList(
#         (0): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#         (1): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (4): IAF(
#       (net): ModuleList(
#         (0): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#         (1): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (5): IAF(
#       (net): ModuleList(
#         (0): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#         (1): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (6): IAF(
#       (net): ModuleList(
#         (0): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#         (1): MADE(
#           (context_input_layer): MaskedLinear(
#             in_features=2, out_features=128, bias=True
#             (context_linear): Linear(in_features=32, out_features=128, bias=False)
#           )
#           (net): Sequential(
#             (0): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (1): ReLU()
#             (2): MaskedLinear(in_features=128, out_features=128, bias=True)
#             (3): ReLU()
#             (4): MaskedLinear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#   )
# )

# %%
train_data.shape
# Out:
# torch.Size([10000, 8, 784])

# %%
_ = model({'data': train_data[:5].cuda().float()}, epoch=100)

# %%
from pythae.trainers import BaseTrainerConfig, BaseTrainer
import torch.optim as optim

train_dataset = DynBinarizedMNIST(train_data)
eval_dataset = DynBinarizedMNIST(eval_data)

training_config = BaseTrainerConfig(
    num_epochs=100,
    learning_rate=1e-3,
    batch_size=64
)

### Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=training_config.learning_rate, eps=1e-4)

### Scheduler
scheduler = torch.optim.lr_scheduler.MultiStepLR(
    optimizer, milestones=[10000], gamma=10**(-1/7), verbose=True
)

trainer = BaseTrainer(
        model=model,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        training_config=training_config,
        optimizer=optimizer,
        scheduler=scheduler,
        callbacks=None,
    )
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
inp = iter(trainer.train_loader).next().data

lim = train_data.shape[1]
im_size = 28#64

torch.manual_seed(8)
idx = torch.randperm(len(inp))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(inp[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(inp[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(inp[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(inp[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')

# %%
#model.warmup = 0
trainer.train()
# Out:
# Model passed sanity check !
#
# Created dummy_output_dir/VAE_IAF_training_2022-10-24_14-24-45.
# Training config, checkpoints and final model will be saved here.
#
# Successfully launched training !
#
#
#
#
#
#
#
#
#
#
# Training of epoch 1/100: 100%|██████████| 157/157 [00:03<00:00, 48.95batch/s]
# Eval of epoch 1/100: 100%|██████████| 157/157 [00:01<00:00, 152.09batch/s]
# --------------------------------------------------------------------------
# Train loss: 232.2448
# Eval loss: 205.7866
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 2/100: 100%|██████████| 157/157 [00:02<00:00, 76.38batch/s]
# Eval of epoch 2/100: 100%|██████████| 157/157 [00:00<00:00, 270.60batch/s]
# --------------------------------------------------------------------------
# Train loss: 195.7729
# Eval loss: 191.5685
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 15/100: 100%|██████████| 157/157 [00:01<00:00, 152.81batch/s]
# Eval of epoch 15/100: 100%|██████████| 157/157 [00:00<00:00, 703.20batch/s]
# --------------------------------------------------------------------------
# Train loss: 170.1641
# Eval loss: 171.1159
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 16/100: 100%|██████████| 157/157 [00:00<00:00, 157.67batch/s]
# Eval of epoch 16/100: 100%|██████████| 157/157 [00:00<00:00, 632.95batch/s]
# --------------------------------------------------------------------------
# Train loss: 169.5515
# Eval loss: 170.5408
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 17/100: 100%|██████████| 157/157 [00:00<00:00, 158.15batch/s]
# Eval of epoch 17/100: 100%|██████████| 157/157 [00:00<00:00, 655.40batch/s]
# --------------------------------------------------------------------------
# Train loss: 168.5807
# Eval loss: 169.5232
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 18/100: 100%|██████████| 157/157 [00:01<00:00, 156.75batch/s]
# Eval of epoch 18/100: 100%|██████████| 157/157 [00:00<00:00, 630.94batch/s]
# --------------------------------------------------------------------------
# Train loss: 167.9287
# Eval loss: 168.9149
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 19/100: 100%|██████████| 157/157 [00:00<00:00, 159.97batch/s]
# Eval of epoch 19/100: 100%|██████████| 157/157 [00:00<00:00, 638.80batch/s]
# --------------------------------------------------------------------------
# Train loss: 167.1928
# Eval loss: 168.698
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 20/100: 100%|██████████| 157/157 [00:01<00:00, 152.83batch/s]
# Eval of epoch 20/100: 100%|██████████| 157/157 [00:00<00:00, 575.60batch/s]
# --------------------------------------------------------------------------
# Train loss: 166.6967
# Eval loss: 168.0917
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 21/100: 100%|██████████| 157/157 [00:01<00:00, 147.68batch/s]
# Eval of epoch 21/100: 100%|██████████| 157/157 [00:00<00:00, 666.53batch/s]
# --------------------------------------------------------------------------
# Train loss: 166.1192
# Eval loss: 167.6508
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 22/100: 100%|██████████| 157/157 [00:00<00:00, 164.94batch/s]
# Eval of epoch 22/100: 100%|██████████| 157/157 [00:00<00:00, 703.27batch/s]
# --------------------------------------------------------------------------
# Train loss: 165.6083
# Eval loss: 167.1292
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 23/100: 100%|██████████| 157/157 [00:00<00:00, 157.02batch/s]
# Eval of epoch 23/100: 100%|██████████| 157/157 [00:00<00:00, 656.70batch/s]
# --------------------------------------------------------------------------
# Train loss: 165.1547
# Eval loss: 166.8929
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 24/100: 100%|██████████| 157/157 [00:00<00:00, 161.36batch/s]
# Eval of epoch 24/100: 100%|██████████| 157/157 [00:00<00:00, 668.78batch/s]
# --------------------------------------------------------------------------
# Train loss: 164.468
# Eval loss: 166.8092
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 25/100: 100%|██████████| 157/157 [00:00<00:00, 161.04batch/s]
# Eval of epoch 25/100: 100%|██████████| 157/157 [00:00<00:00, 651.24batch/s]
# --------------------------------------------------------------------------
# Train loss: 164.1027
# Eval loss: 165.941
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 26/100: 100%|██████████| 157/157 [00:00<00:00, 159.54batch/s]
# Eval of epoch 26/100: 100%|██████████| 157/157 [00:00<00:00, 673.73batch/s]
# --------------------------------------------------------------------------
# Train loss: 163.7848
# Eval loss: 166.4144
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 40/100: 100%|██████████| 157/157 [00:00<00:00, 159.60batch/s]
# Eval of epoch 40/100: 100%|██████████| 157/157 [00:00<00:00, 670.72batch/s]
# --------------------------------------------------------------------------
# Train loss: 159.5385
# Eval loss: 163.3519
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 41/100: 100%|██████████| 157/157 [00:00<00:00, 167.69batch/s]
# Eval of epoch 41/100: 100%|██████████| 157/157 [00:00<00:00, 664.90batch/s]
# --------------------------------------------------------------------------
# Train loss: 159.3103
# Eval loss: 163.3019
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 42/100: 100%|██████████| 157/157 [00:01<00:00, 143.28batch/s]
# Eval of epoch 42/100: 100%|██████████| 157/157 [00:00<00:00, 740.59batch/s]
# --------------------------------------------------------------------------
# Train loss: 159.0485
# Eval loss: 163.3484
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 43/100: 100%|██████████| 157/157 [00:00<00:00, 160.43batch/s]
# Eval of epoch 43/100: 100%|██████████| 157/157 [00:00<00:00, 660.79batch/s]
# --------------------------------------------------------------------------
# Train loss: 158.936
# Eval loss: 163.1127
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 44/100: 100%|██████████| 157/157 [00:00<00:00, 158.92batch/s]
# Eval of epoch 44/100: 100%|██████████| 157/157 [00:00<00:00, 679.18batch/s]
# --------------------------------------------------------------------------
# Train loss: 158.7765
# Eval loss: 163.0693
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 45/100: 100%|██████████| 157/157 [00:00<00:00, 172.36batch/s]
# Eval of epoch 45/100: 100%|██████████| 157/157 [00:00<00:00, 757.98batch/s]
# --------------------------------------------------------------------------
# Train loss: 158.7813
# Eval loss: 163.0714
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 46/100: 100%|██████████| 157/157 [00:01<00:00, 152.50batch/s]
# Eval of epoch 46/100: 100%|██████████| 157/157 [00:00<00:00, 618.97batch/s]
# --------------------------------------------------------------------------
# Train loss: 158.4141
# Eval loss: 162.9746
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 47/100: 100%|██████████| 157/157 [00:01<00:00, 152.60batch/s]
# Eval of epoch 47/100: 100%|██████████| 157/157 [00:00<00:00, 536.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 158.2656
# Eval loss: 162.9178
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 48/100: 100%|██████████| 157/157 [00:00<00:00, 160.60batch/s]
# Eval of epoch 48/100: 100%|██████████| 157/157 [00:00<00:00, 662.62batch/s]
# --------------------------------------------------------------------------
# Train loss: 158.0203
# Eval loss: 162.827
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# Training of epoch 49/100: 100%|██████████| 157/157 [00:00<00:00, 162.20batch/s]
# Eval of epoch 49/100: 100%|██████████| 157/157 [00:00<00:00, 756.74batch/s]
# --------------------------------------------------------------------------
# Train loss: 157.9377
# Eval loss: 162.8624
# --------------------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-03.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [32,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [33,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [34,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [35,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [38,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [1,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [3,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [4,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [8,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [12,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [14,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [15,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [16,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [18,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [20,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [22,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [23,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [24,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [25,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [27,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [29,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [30,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [407,0,0], thread: [31,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [1,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [3,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [4,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [8,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [12,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [14,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [15,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [16,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [18,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [20,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [22,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [23,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [24,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [25,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [27,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [29,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [30,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [31,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [64,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [65,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [66,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [70,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [72,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [73,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [74,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [75,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [76,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [77,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [78,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [79,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [80,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [81,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [84,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [85,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [88,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [90,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [91,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [92,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [93,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [94,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [95,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [32,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [33,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [34,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [35,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [38,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [40,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [41,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [42,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [45,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [46,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [47,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [48,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [49,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [50,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [51,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [52,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [53,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [54,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [55,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [56,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [57,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [58,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [59,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [60,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [61,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [62,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [63,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [99,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [103,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [104,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [105,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [106,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [108,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [109,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [110,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [113,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [114,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [115,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [118,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [119,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [124,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [126,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [405,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [64,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [65,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [66,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [70,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [72,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [73,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [74,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [75,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [76,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [77,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [78,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [79,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [80,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [81,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [84,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [85,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [404,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ...
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [8,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [12,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [14,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [15,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [16,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [18,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [20,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [22,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [23,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [24,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [25,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [27,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [29,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [30,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [31,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [99,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [103,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [104,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [105,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [106,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [108,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [109,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [110,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [113,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [114,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [115,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [118,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [119,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [124,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [126,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:129: operator(): block: [406,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 34' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000032vscode-remote?line=0'>1</a> #model.warmup = 0
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000032vscode-remote?line=1'>2</a> trainer.train()
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py:341, in BaseTrainer.train(self, log_output_dir)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=331'>332</a> self.callback_handler.on_epoch_begin(
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=332'>333</a>     training_config=self.training_config,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=333'>334</a>     epoch=epoch,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=334'>335</a>     train_loader=self.train_loader,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=335'>336</a>     eval_loader=self.eval_loader,
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=336'>337</a> )
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=338'>339</a> metrics = {}
# --> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=340'>341</a> epoch_train_loss = self.train_step(epoch)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=341'>342</a> metrics["train_epoch_loss"] = epoch_train_loss
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=343'>344</a> if self.eval_dataset is not None:
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py:487, in BaseTrainer.train_step(self, epoch)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=480'>481</a> inputs = self._set_inputs_to_device(inputs)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=482'>483</a> model_output = self.model(
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=483'>484</a>     inputs, epoch=epoch, dataset_size=len(self.train_loader.dataset)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=484'>485</a> )
# --> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=486'>487</a> self._optimizers_step(model_output)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=488'>489</a> loss = model_output.loss
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=490'>491</a> epoch_loss += loss.item()
#
# File ~/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py:236, in BaseTrainer._optimizers_step(self, model_output)
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=232'>233</a> loss = model_output.loss
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=234'>235</a> self.optimizer.zero_grad()
# --> <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=235'>236</a> loss.backward()
#     <a href='file:///home/clement/Documents/rvae/benchmark_VAE/src/pythae/trainers/base_trainer/base_trainer.py?line=236'>237</a> self.optimizer.step()
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py?line=386'>387</a> if has_torch_function_unary(self):
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py?line=387'>388</a>     return handle_torch_function(
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py?line=388'>389</a>         Tensor.backward,
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py?line=389'>390</a>         (self,),
#    (...)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py?line=393'>394</a>         create_graph=create_graph,
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py?line=394'>395</a>         inputs=inputs)
# --> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/_tensor.py?line=395'>396</a> torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py?line=167'>168</a>     retain_graph = create_graph
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py?line=169'>170</a> # The reason we repeat same the comment below is that
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py?line=170'>171</a> # some Python versions print out the first line of a multi-line function
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py?line=171'>172</a> # calls in the traceback and some print out the last line
# --> <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py?line=172'>173</a> Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py?line=173'>174</a>     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     <a href='file:///home/clement/anaconda3/envs/rhmc/lib/python3.8/site-packages/torch/autograd/__init__.py?line=174'>175</a>     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
model_rec = model

# %%
z = torch.randn(10, 2).cuda()

# %%
gen = model_rec.generate(z).detach().cpu()
gen.shape
# Out:
# torch.Size([10, 8, 1, 28, 28])
# Training of epoch 70/100:  94%|█████████▍| 148/157 [00:17<00:00, 23.26batch/s]

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(train_data))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(gen[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')

# %%
inp = iter(trainer.eval_loader).next()

output = model_rec(inp, epoch=100000)
recon = output.recon_x.detach()
z_seq = output.z_seq.detach()

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(recon))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(recon))

# Train recon
fig, axes = plt.subplots(4, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    i, t = 1, k
    axes[1][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 2, k
    axes[2][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    i, t = 3, k
    axes[3][k].imshow(recon[i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')
# Out:
# Training of epoch 54/100:  71%|███████▏  | 112/157 [00:21<00:02, 21.85batch/s]

# %%
inp.data.shape
# Out:
# torch.Size([64, 8, 784])

# %%
a = torch.tensor([[1], [2], [3]])
a.repeat(1, 2).reshape(-1, 1)
# Out:
# tensor([[1],
#         [1],
#         [2],
#         [2],
#         [3],
#         [3]])

# %%
inp = iter(trainer.eval_loader).next()

output = model_rec({'data': inp.data[:10].repeat(1, 64, 1).reshape(-1, 8, 784)}, epoch=100000)
recon = output.recon_x.detach()
z_seq = output.z_seq.detach()

# %%
c = ['b', 'r', 'orange', 'yellow','cyan', 'purple', 'green', 'black', 'pink', 'brown']
for i in range(8):
    for j in range(10):
        plt.scatter(z_seq[64*j:64*(j+1), i, 0].cpu(), z_seq[64*j:64*(j+1), i, 1].cpu(), c=c[j])
    plt.show()

# %%
lim = 8
im_size = 28

torch.manual_seed(8)
idx = torch.randperm(len(eval_data))

# Train recon
fig, axes = plt.subplots(8, lim, figsize=(lim, 4))
torch.manual_seed(88)
for k in range(lim):
    i, t = 0, k
    axes[0][k].imshow(eval_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[0][k].axis('off')
    axes[1][k].imshow(recon[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[1][k].axis('off')
    i, t = 1, k
    axes[2][k].imshow(eval_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[2][k].axis('off')
    axes[3][k].imshow(recon[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[3][k].axis('off')
    i, t = 2, k
    axes[4][k].imshow(eval_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[4][k].axis('off')
    axes[5][k].imshow(recon[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[5][k].axis('off')
    i, t = 3, k
    axes[6][k].imshow(eval_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[6][k].axis('off')
    axes[7][k].imshow(recon[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
    axes[7][k].axis('off')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb Cell 29' in <cell line: 10>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000028vscode-remote?line=9'>10</a> for k in range(lim):
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000028vscode-remote?line=10'>11</a>     i, t = 0, k
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000028vscode-remote?line=11'>12</a>     axes[0][k].imshow(eval_data[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000028vscode-remote?line=12'>13</a>     axes[0][k].axis('off')
#      <a href='vscode-notebook-cell://ssh-remote%2Bthese_clement/home/clement/Documents/rvae/benchmark_VAE/examples/notebooks/models_training/lvae_iaf.ipynb#ch0000028vscode-remote?line=13'>14</a>     axes[1][k].imshow(recon[idx][i, t].reshape(im_size, im_size).cpu(), cmap='gray')
#
# RuntimeError: shape '[28, 28]' is invalid for input of size 4096
